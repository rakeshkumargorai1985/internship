# %%
pip install bs4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install request
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement request (from versions: none)
# ERROR: No matching distribution found for request

# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
page  = requests.get('https://presidentofindia.nic.in/former-presidents')
page
# Out:
# <Response [200]>

# %%
soup= BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <link href="/manifest.json" rel="manifest"/>
# <meta content="" name="theme-color"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="default" name="apple-mobile-web-app-status-bar-style"/>
# <meta content="President of India" name="apple-mobile-web-app-title"/>
# <meta content="Drupal 9 (https://www.drupal.org)" name="Generator"/>
# <meta content="width" name="MobileOptimized"/>
# <meta content="true" name="HandheldFriendly"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="" rel="apple-touch-icon" sizes="192x192"/>
# <link href="/iphone5_splash.png" media="(device-width: 320px) and (device-height: 568px) and (-webkit-device-pixel-ratio: 2)" rel="apple-touch-startup-image"/>
# <link href="/iphone6_splash.png" media="(device-width: 375px) and (device-height: 667px) and (-webkit-device-pixel-ratio: 2)" rel="apple-touch-startup-image"/>
# ...

# %%
data = soup.find_all('div', class_="desc-sec")
data
# Out:
# [<div class="desc-sec">
#  <h3>Shri Ram Nath Kovind</h3>
#  <h5>14th President of India</h5>
#  </div>,
#  <div class="desc-sec">
#  <h3>Shri Pranab Mukherjee</h3>
#  <h5>13th President of India</h5>
#  </div>,
#  <div class="desc-sec">
#  <h3>Smt Pratibha Devisingh Patil</h3>
#  <h5>12th President of India</h5>
#  </div>,
#  <div class="desc-sec">
#  <h3>DR. A.P.J. Abdul Kalam</h3>
#  <h5>11th President of India</h5>
#  </div>,
#  <div class="desc-sec">
#  <h3>Shri K. R. Narayanan</h3>
#  <h5>10th President of India</h5>
#  </div>,
#  <div class="desc-sec">
#  <h3>Dr Shankar Dayal Sharma</h3>
#  <h5>9th  President of India</h5>
#  </div>,
#  <div class="desc-sec">
#  <h3>Shri R Venkataraman</h3>
#  <h5>8th President of India</h5>
#  </div>,
#  <div class="desc-sec">
#  <h3>Giani Zail Singh</h3>
#  <h5>7th President of India</h5>
#  </div>,
#  <div class="desc-sec">
#  <h3>Shri Neelam Sanjiva Reddy</h3>
#  <h5>6th President of India</h5>
#  </div>,
#  <div class="desc-sec">
# ...

# %%
name=[]
for tag in data:
    name.append(tag.name)
name
# Out:
# ['div',
#  'div',
#  'div',
#  'div',
#  'div',
#  'div',
#  'div',
#  'div',
#  'div',
#  'div',
#  'div',
#  'div',
#  'div',
#  'div']

# %%
name=[]
for tag in data:
    name.append(tag.text)
name
# Out:
# ['\nShri Ram Nath Kovind\n14th President of India\n',
#  '\nShri Pranab Mukherjee\n13th President of India\n',
#  '\nSmt Pratibha Devisingh Patil\n12th President of India\n',
#  '\nDR. A.P.J. Abdul Kalam\n11th President of India\n',
#  '\nShri K. R. Narayanan\n10th President of India\n',
#  '\nDr Shankar Dayal Sharma\n9th  President of India\n',
#  '\nShri R Venkataraman\n8th President of India\n',
#  '\nGiani Zail Singh\n7th President of India\n',
#  '\nShri Neelam Sanjiva Reddy\n6th President of India\n',
#  '\nDr. Fakhruddin Ali Ahmed\n5th President of India\n',
#  '\nShri Varahagiri Venkata Giri\n4th President of India\n',
#  '\nDr. Zakir Husain\n3rd President of India\n',
#  '\nDr. Sarvepalli Radhakrishnan\n2nd President of India\n',
#  '\nDr. Rajendra Prasad\n1st President of India\n']

# %%
name=[]
for tag in data:
    name.append(tag.text.strip())
name
# Out:
# ['Shri Ram Nath Kovind\n14th President of India',
#  'Shri Pranab Mukherjee\n13th President of India',
#  'Smt Pratibha Devisingh Patil\n12th President of India',
#  'DR. A.P.J. Abdul Kalam\n11th President of India',
#  'Shri K. R. Narayanan\n10th President of India',
#  'Dr Shankar Dayal Sharma\n9th  President of India',
#  'Shri R Venkataraman\n8th President of India',
#  'Giani Zail Singh\n7th President of India',
#  'Shri Neelam Sanjiva Reddy\n6th President of India',
#  'Dr. Fakhruddin Ali Ahmed\n5th President of India',
#  'Shri Varahagiri Venkata Giri\n4th President of India',
#  'Dr. Zakir Husain\n3rd President of India',
#  'Dr. Sarvepalli Radhakrishnan\n2nd President of India',
#  'Dr. Rajendra Prasad\n1st President of India']

# %%
name=[]
for tag in data:
    president_name = tag.find('h3').text
    name.append(president_name.strip())
name
# Out:
# ['Shri Ram Nath Kovind',
#  'Shri Pranab Mukherjee',
#  'Smt Pratibha Devisingh Patil',
#  'DR. A.P.J. Abdul Kalam',
#  'Shri K. R. Narayanan',
#  'Dr Shankar Dayal Sharma',
#  'Shri R Venkataraman',
#  'Giani Zail Singh',
#  'Shri Neelam Sanjiva Reddy',
#  'Dr. Fakhruddin Ali Ahmed',
#  'Shri Varahagiri Venkata Giri',
#  'Dr. Zakir Husain',
#  'Dr. Sarvepalli Radhakrishnan',
#  'Dr. Rajendra Prasad']

# %%
term=[]
for tag in data:
    terms_of_office = tag.find('h5').text
    term.append(terms_of_office.strip())
term
# Out:
# ['14th President of India',
#  '13th President of India',
#  '12th President of India',
#  '11th President of India',
#  '10th President of India',
#  '9th  President of India',
#  '8th President of India',
#  '7th President of India',
#  '6th President of India',
#  '5th President of India',
#  '4th President of India',
#  '3rd President of India',
#  '2nd President of India',
#  '1st President of India']

# %%
import pandas as pd
df= pd.DataFrame({'president_name':name,'terms_of_office':term})
df
# Out:
#                   president_name          terms_of_office
# 0           Shri Ram Nath Kovind  14th President of India
# 1          Shri Pranab Mukherjee  13th President of India
# 2   Smt Pratibha Devisingh Patil  12th President of India
# 3         DR. A.P.J. Abdul Kalam  11th President of India
# 4           Shri K. R. Narayanan  10th President of India
# 5        Dr Shankar Dayal Sharma  9th  President of India
# 6            Shri R Venkataraman   8th President of India
# 7               Giani Zail Singh   7th President of India
# 8      Shri Neelam Sanjiva Reddy   6th President of India
# 9       Dr. Fakhruddin Ali Ahmed   5th President of India
# 10  Shri Varahagiri Venkata Giri   4th President of India
# 11              Dr. Zakir Husain   3rd President of India
# 12  Dr. Sarvepalli Radhakrishnan   2nd President of India
# 13           Dr. Rajendra Prasad   1st President of India

# %%
president_names = []
term_of_office = []

for item in data:
    parts = item.split('\n')
    if len(parts) == 2:
        president_names.append(parts[0])
        term_of_office.append(parts[1])
president_names
term_of_office
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 5
#       2 term_of_office = []
#       4 for item in data:
# ----> 5     parts = item.split('\n')
#       6     if len(parts) == 2:
#       7         president_names.append(parts[0])
#
# TypeError: 'NoneType' object is not callable

# %%
president=[]
for tag in data:
    president.append(tag.text.strip())
president
# Out:
# ['Shri Ram Nath Kovind\n14th President of India',
#  'Shri Pranab Mukherjee\n13th President of India',
#  'Smt Pratibha Devisingh Patil\n12th President of India',
#  'DR. A.P.J. Abdul Kalam\n11th President of India',
#  'Shri K. R. Narayanan\n10th President of India',
#  'Dr Shankar Dayal Sharma\n9th  President of India',
#  'Shri R Venkataraman\n8th President of India',
#  'Giani Zail Singh\n7th President of India',
#  'Shri Neelam Sanjiva Reddy\n6th President of India',
#  'Dr. Fakhruddin Ali Ahmed\n5th President of India',
#  'Shri Varahagiri Venkata Giri\n4th President of India',
#  'Dr. Zakir Husain\n3rd President of India',
#  'Dr. Sarvepalli Radhakrishnan\n2nd President of India',
#  'Dr. Rajendra Prasad\n1st President of India']

# %%
president_names = []
term_of_office = []

for item in president:
    parts = item.split('\n')
    if len(parts) == 2:
        president_names.append(parts[0])
        term_of_office.append(parts[1])
president_names
term_of_office
# Out:
# ['14th President of India',
#  '13th President of India',
#  '12th President of India',
#  '11th President of India',
#  '10th President of India',
#  '9th  President of India',
#  '8th President of India',
#  '7th President of India',
#  '6th President of India',
#  '5th President of India',
#  '4th President of India',
#  '3rd President of India',
#  '2nd President of India',
#  '1st President of India']

# %%
president_names = []


for item in president:
    parts = item.split('\n')
    if len(parts) > 1:
        president_names.append(parts[0])
        term_of_office.append(parts[1])
president_names
# Out:
# ['Shri Ram Nath Kovind',
#  'Shri Pranab Mukherjee',
#  'Smt Pratibha Devisingh Patil',
#  'DR. A.P.J. Abdul Kalam',
#  'Shri K. R. Narayanan',
#  'Dr Shankar Dayal Sharma',
#  'Shri R Venkataraman',
#  'Giani Zail Singh',
#  'Shri Neelam Sanjiva Reddy',
#  'Dr. Fakhruddin Ali Ahmed',
#  'Shri Varahagiri Venkata Giri',
#  'Dr. Zakir Husain',
#  'Dr. Sarvepalli Radhakrishnan',
#  'Dr. Rajendra Prasad']

# %%
term_of_office = []

for item in president:
    parts = item.split('\n')
    if len(parts) == 2:
        president_names.append(parts[0])
        term_of_office.append(parts[1])

term_of_office
# Out:
# ['14th President of India',
#  '13th President of India',
#  '12th President of India',
#  '11th President of India',
#  '10th President of India',
#  '9th  President of India',
#  '8th President of India',
#  '7th President of India',
#  '6th President of India',
#  '5th President of India',
#  '4th President of India',
#  '3rd President of India',
#  '2nd President of India',
#  '1st President of India']

# %%
import pandas as pd
df= pd.DataFrame({'president_name':president_names,'terms_of_office':term_of_office})
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 2
#       1 import pandas as pd
# ----> 2 df= pd.DataFrame({'president_name':president_names,'terms_of_office':term_of_office})
#       3 df
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:664, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     658     mgr = self._init_mgr(
#     659         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     660     )
#     662 elif isinstance(data, dict):
#     663     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 664     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     665 elif isinstance(data, ma.MaskedArray):
#     666     import numpy.ma.mrecords as mrecords
#
# ...

# %%
import pandas as pd
datas= pd.DataFrame({'president_name':president_names,'terms_of_office':term_of_office})
datas
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 2
#       1 import pandas as pd
# ----> 2 datas= pd.DataFrame({'president_name':president_names,'terms_of_office':term_of_office})
#       3 datas
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:664, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     658     mgr = self._init_mgr(
#     659         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     660     )
#     662 elif isinstance(data, dict):
#     663     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 664     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     665 elif isinstance(data, ma.MaskedArray):
#     666     import numpy.ma.mrecords as mrecords
#
# ...

# %%
import pandas as pd
df= pd.DataFrame({'president_name':name,'terms_of_office':term})
df
# Out:
#                   president_name          terms_of_office
# 0           Shri Ram Nath Kovind  14th President of India
# 1          Shri Pranab Mukherjee  13th President of India
# 2   Smt Pratibha Devisingh Patil  12th President of India
# 3         DR. A.P.J. Abdul Kalam  11th President of India
# 4           Shri K. R. Narayanan  10th President of India
# 5        Dr Shankar Dayal Sharma  9th  President of India
# 6            Shri R Venkataraman   8th President of India
# 7               Giani Zail Singh   7th President of India
# 8      Shri Neelam Sanjiva Reddy   6th President of India
# 9       Dr. Fakhruddin Ali Ahmed   5th President of India
# 10  Shri Varahagiri Venkata Giri   4th President of India
# 11              Dr. Zakir Husain   3rd President of India
# 12  Dr. Sarvepalli Radhakrishnan   2nd President of India
# 13           Dr. Rajendra Prasad   1st President of India

# %%
import pandas as pd
datas= pd.DataFrame({'president_name':president_names,'terms_of_office':term_of_office})
datas
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 2
#       1 import pandas as pd
# ----> 2 datas= pd.DataFrame({'president_name':president_names,'terms_of_office':term_of_office})
#       3 datas
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:664, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     658     mgr = self._init_mgr(
#     659         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     660     )
#     662 elif isinstance(data, dict):
#     663     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 664     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     665 elif isinstance(data, ma.MaskedArray):
#     666     import numpy.ma.mrecords as mrecords
#
# ...

# %%
president_names = []


for item in president:
    parts = item.split('\n')
    if len(parts) > 1:
        president_names.append(parts[0])
        term_of_office.append(parts[1])
president_names
# Out:
# ['Shri Ram Nath Kovind',
#  'Shri Pranab Mukherjee',
#  'Smt Pratibha Devisingh Patil',
#  'DR. A.P.J. Abdul Kalam',
#  'Shri K. R. Narayanan',
#  'Dr Shankar Dayal Sharma',
#  'Shri R Venkataraman',
#  'Giani Zail Singh',
#  'Shri Neelam Sanjiva Reddy',
#  'Dr. Fakhruddin Ali Ahmed',
#  'Shri Varahagiri Venkata Giri',
#  'Dr. Zakir Husain',
#  'Dr. Sarvepalli Radhakrishnan',
#  'Dr. Rajendra Prasad']

# %%
term_of_office = []

for item in president:
    parts = item.split('\n')
    if len(parts) > 1:
        president_names.append(parts[0])
        term_of_office.append(parts[1])

term_of_office
# Out:
# ['14th President of India',
#  '13th President of India',
#  '12th President of India',
#  '11th President of India',
#  '10th President of India',
#  '9th  President of India',
#  '8th President of India',
#  '7th President of India',
#  '6th President of India',
#  '5th President of India',
#  '4th President of India',
#  '3rd President of India',
#  '2nd President of India',
#  '1st President of India']

# %%
import pandas as pd
datas= pd.DataFrame({'president_name':president_names,'terms_of_office':term_of_office})
datas
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 2
#       1 import pandas as pd
# ----> 2 datas= pd.DataFrame({'president_name':president_names,'terms_of_office':term_of_office})
#       3 datas
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:664, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     658     mgr = self._init_mgr(
#     659         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     660     )
#     662 elif isinstance(data, dict):
#     663     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 664     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     665 elif isinstance(data, ma.MaskedArray):
#     666     import numpy.ma.mrecords as mrecords
#
# ...

# %%
import pandas as pd
datas= pd.DataFrame({'president_name':president_names})
datas
# Out:
#                   president_name
# 0           Shri Ram Nath Kovind
# 1          Shri Pranab Mukherjee
# 2   Smt Pratibha Devisingh Patil
# 3         DR. A.P.J. Abdul Kalam
# 4           Shri K. R. Narayanan
# 5        Dr Shankar Dayal Sharma
# 6            Shri R Venkataraman
# 7               Giani Zail Singh
# 8      Shri Neelam Sanjiva Reddy
# 9       Dr. Fakhruddin Ali Ahmed
# 10  Shri Varahagiri Venkata Giri
# 11              Dr. Zakir Husain
# 12  Dr. Sarvepalli Radhakrishnan
# 13           Dr. Rajendra Prasad
# 14          Shri Ram Nath Kovind
# 15         Shri Pranab Mukherjee
# 16  Smt Pratibha Devisingh Patil
# 17        DR. A.P.J. Abdul Kalam
# 18          Shri K. R. Narayanan
# 19       Dr Shankar Dayal Sharma
# 20           Shri R Venkataraman
# 21              Giani Zail Singh
# 22     Shri Neelam Sanjiva Reddy
# 23      Dr. Fakhruddin Ali Ahmed
# 24  Shri Varahagiri Venkata Giri
# 25              Dr. Zakir Husain
# 26  Dr. Sarvepalli Radhakrishnan
# ...

# %%
president_na = []


for item in president:
    parts = item.split('\n')
    if len(parts) > 1:
        president_na.append(parts[0])
      )
president_na
# Out:
#   File <tokenize>:8
#     )
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
president_na = []


for item in president:
    parts = item.split('\n')
    if len(parts) > 1:
        president_na.append(parts[0])      
president_na
# Out:
# ['Shri Ram Nath Kovind',
#  'Shri Pranab Mukherjee',
#  'Smt Pratibha Devisingh Patil',
#  'DR. A.P.J. Abdul Kalam',
#  'Shri K. R. Narayanan',
#  'Dr Shankar Dayal Sharma',
#  'Shri R Venkataraman',
#  'Giani Zail Singh',
#  'Shri Neelam Sanjiva Reddy',
#  'Dr. Fakhruddin Ali Ahmed',
#  'Shri Varahagiri Venkata Giri',
#  'Dr. Zakir Husain',
#  'Dr. Sarvepalli Radhakrishnan',
#  'Dr. Rajendra Prasad']

# %%
term_of = []

for item in president:
    parts = item.split('\n')
    if len(parts) > 1:
       
        term_of.append(parts[1])

term_of
# Out:
# ['14th President of India',
#  '13th President of India',
#  '12th President of India',
#  '11th President of India',
#  '10th President of India',
#  '9th  President of India',
#  '8th President of India',
#  '7th President of India',
#  '6th President of India',
#  '5th President of India',
#  '4th President of India',
#  '3rd President of India',
#  '2nd President of India',
#  '1st President of India']

# %%
import pandas as pd
datas= pd.DataFrame({'president_name':president_na,'terms_of_office':term_of})
datas
# Out:
#                   president_name          terms_of_office
# 0           Shri Ram Nath Kovind  14th President of India
# 1          Shri Pranab Mukherjee  13th President of India
# 2   Smt Pratibha Devisingh Patil  12th President of India
# 3         DR. A.P.J. Abdul Kalam  11th President of India
# 4           Shri K. R. Narayanan  10th President of India
# 5        Dr Shankar Dayal Sharma  9th  President of India
# 6            Shri R Venkataraman   8th President of India
# 7               Giani Zail Singh   7th President of India
# 8      Shri Neelam Sanjiva Reddy   6th President of India
# 9       Dr. Fakhruddin Ali Ahmed   5th President of India
# 10  Shri Varahagiri Venkata Giri   4th President of India
# 11              Dr. Zakir Husain   3rd President of India
# 12  Dr. Sarvepalli Radhakrishnan   2nd President of India
# 13           Dr. Rajendra Prasad   1st President of India

# %%
import pandas as pd
datas= pd.DataFrame({'terms_of_office':term_of_office})
datas
# Out:
#             terms_of_office
# 0   14th President of India
# 1   13th President of India
# 2   12th President of India
# 3   11th President of India
# 4   10th President of India
# 5   9th  President of India
# 6    8th President of India
# 7    7th President of India
# 8    6th President of India
# 9    5th President of India
# 10   4th President of India
# 11   3rd President of India
# 12   2nd President of India
# 13   1st President of India

# %%
page  = requests.get('https://www.icc-cricket.com/rankings/mens/team-rankings/odi')
page
# Out:
# <Response [200]>

# %%
soup= BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="ICC Men's ODI Team Rankings | ICC" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official International Cricket Council ranking for One Day International (ODI) cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official International Cricket Council ranking for One Day International (ODI) cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC Men's ODI Team Rankings | ICC" property="og:title"/>
# ...

# %%
data = soup.find_all('td', class_="table-body__cell rankings-table__team")
data
# Out:
# [<td class="table-body__cell rankings-table__team">
#  <span class="flag-15 table-body_logo IND"></span>
#  <span class="u-hide-phablet">India</span>
#  <span class="u-show-phablet">IND</span>
#  </td>,
#  <td class="table-body__cell rankings-table__team">
#  <span class="flag-15 table-body_logo PAK"></span>
#  <span class="u-hide-phablet">Pakistan</span>
#  <span class="u-show-phablet">PAK</span>
#  </td>,
#  <td class="table-body__cell rankings-table__team">
#  <span class="flag-15 table-body_logo ENG"></span>
#  <span class="u-hide-phablet">England</span>
#  <span class="u-show-phablet">ENG</span>
#  </td>,
#  <td class="table-body__cell rankings-table__team">
#  <span class="flag-15 table-body_logo NZ"></span>
#  <span class="u-hide-phablet">New Zealand</span>
#  <span class="u-show-phablet">NZ</span>
#  </td>,
#  <td class="table-body__cell rankings-table__team">
#  <span class="flag-15 table-body_logo SA"></span>
#  <span class="u-hide-phablet">South Africa</span>
# ...

# %%
team_name = data.find_all('span', class_="u-hide-phablet")
team_name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 team_name = data.find_all('span', class_="u-hide-phablet")
#       2 team_name
#
# File ~\anaconda3\lib\site-packages\bs4\element.py:2289, in ResultSet.__getattr__(self, key)
#    2287 def __getattr__(self, key):
#    2288     """Raise a helpful exception to explain a common code fix."""
# -> 2289     raise AttributeError(
#    2290         "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2291     )
#
# AttributeError: ResultSet object has no attribute 'find_all'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
data = soup.find_all('span', class_="u-hide-phablet")
data
# Out:
# [<span class="u-hide-phablet">Australia</span>,
#  <span class="u-hide-phablet">India</span>,
#  <span class="u-hide-phablet">Pakistan</span>,
#  <span class="u-hide-phablet">England</span>,
#  <span class="u-hide-phablet">New Zealand</span>,
#  <span class="u-hide-phablet">South Africa</span>,
#  <span class="u-hide-phablet">Sri Lanka</span>,
#  <span class="u-hide-phablet">Bangladesh</span>,
#  <span class="u-hide-phablet">Afghanistan</span>,
#  <span class="u-hide-phablet">West Indies</span>,
#  <span class="u-hide-phablet">Zimbabwe</span>,
#  <span class="u-hide-phablet">Scotland</span>,
#  <span class="u-hide-phablet">Ireland</span>,
#  <span class="u-hide-phablet">Netherlands</span>,
#  <span class="u-hide-phablet">Nepal</span>,
#  <span class="u-hide-phablet">Namibia</span>,
#  <span class="u-hide-phablet">United States</span>,
#  <span class="u-hide-phablet">Oman</span>,
#  <span class="u-hide-phablet">UAE</span>]

# %%
team_name=[]
for tag in data:    
    team_name.append(tag.text.strip())
team_name
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 3
#       1 team_name=[]
#       2 for tag in data:
# ----> 3     team_name.append(tag.strip())
#       4 team_name
#
# TypeError: 'NoneType' object is not callable

# %%
team_name=[]
for tag in data:    
    team_name.append(tag.text.strip())
team_name
# Out:
# ['Australia',
#  'India',
#  'Pakistan',
#  'England',
#  'New Zealand',
#  'South Africa',
#  'Sri Lanka',
#  'Bangladesh',
#  'Afghanistan',
#  'West Indies',
#  'Zimbabwe',
#  'Scotland',
#  'Ireland',
#  'Netherlands',
#  'Nepal',
#  'Namibia',
#  'United States',
#  'Oman',
#  'UAE']

# %%
match = soup.find_all('td', class_="table-body__cell u-center-text")
match
# Out:
# [<td class="table-body__cell u-center-text">39</td>,
#  <td class="table-body__cell u-center-text">4,516</td>,
#  <td class="table-body__cell u-center-text">27</td>,
#  <td class="table-body__cell u-center-text">3,102</td>,
#  <td class="table-body__cell u-center-text">27</td>,
#  <td class="table-body__cell u-center-text">2,790</td>,
#  <td class="table-body__cell u-center-text">30</td>,
#  <td class="table-body__cell u-center-text">3,057</td>,
#  <td class="table-body__cell u-center-text">22</td>,
#  <td class="table-body__cell u-center-text">2,218</td>,
#  <td class="table-body__cell u-center-text">37</td>,
#  <td class="table-body__cell u-center-text">3,448</td>,
#  <td class="table-body__cell u-center-text">32</td>,
#  <td class="table-body__cell u-center-text">2,941</td>,
#  <td class="table-body__cell u-center-text">21</td>,
#  <td class="table-body__cell u-center-text">1,687</td>,
#  <td class="table-body__cell u-center-text">38</td>,
# ...

# %%
all_match=[]
for tag in match:    
    all_match.append(tag.text.strip())
all_match
# Out:
# ['39',
#  '4,516',
#  '27',
#  '3,102',
#  '27',
#  '2,790',
#  '30',
#  '3,057',
#  '22',
#  '2,218',
#  '37',
#  '3,448',
#  '32',
#  '2,941',
#  '21',
#  '1,687',
#  '38',
#  '2,582',
#  '30',
#  '1,641',
#  '33',
#  '1,662',
#  '24',
#  '1,052',
#  '28',
#  '1,044',
#  '42',
#  '1,446',
#  '28',
#  '813',
#  '31',
#  '808',
#  '24',
#  '525',
#  '41',
#  '617']

# %%
alternate_data = match[::2]

# %%
alternate_data
# Out:
# [<td class="table-body__cell u-center-text">39</td>,
#  <td class="table-body__cell u-center-text">27</td>,
#  <td class="table-body__cell u-center-text">27</td>,
#  <td class="table-body__cell u-center-text">30</td>,
#  <td class="table-body__cell u-center-text">22</td>,
#  <td class="table-body__cell u-center-text">37</td>,
#  <td class="table-body__cell u-center-text">32</td>,
#  <td class="table-body__cell u-center-text">21</td>,
#  <td class="table-body__cell u-center-text">38</td>,
#  <td class="table-body__cell u-center-text">30</td>,
#  <td class="table-body__cell u-center-text">33</td>,
#  <td class="table-body__cell u-center-text">24</td>,
#  <td class="table-body__cell u-center-text">28</td>,
#  <td class="table-body__cell u-center-text">42</td>,
#  <td class="table-body__cell u-center-text">28</td>,
#  <td class="table-body__cell u-center-text">31</td>,
#  <td class="table-body__cell u-center-text">24</td>,
#  <td class="table-body__cell u-center-text">41</td>]

# %%
alternates_data = match[::1]
alternates_data
# Out:
# [<td class="table-body__cell u-center-text">39</td>,
#  <td class="table-body__cell u-center-text">4,516</td>,
#  <td class="table-body__cell u-center-text">27</td>,
#  <td class="table-body__cell u-center-text">3,102</td>,
#  <td class="table-body__cell u-center-text">27</td>,
#  <td class="table-body__cell u-center-text">2,790</td>,
#  <td class="table-body__cell u-center-text">30</td>,
#  <td class="table-body__cell u-center-text">3,057</td>,
#  <td class="table-body__cell u-center-text">22</td>,
#  <td class="table-body__cell u-center-text">2,218</td>,
#  <td class="table-body__cell u-center-text">37</td>,
#  <td class="table-body__cell u-center-text">3,448</td>,
#  <td class="table-body__cell u-center-text">32</td>,
#  <td class="table-body__cell u-center-text">2,941</td>,
#  <td class="table-body__cell u-center-text">21</td>,
#  <td class="table-body__cell u-center-text">1,687</td>,
#  <td class="table-body__cell u-center-text">38</td>,
# ...

# %%
selected_data = match[1::2]
selected_data
# Out:
# [<td class="table-body__cell u-center-text">4,516</td>,
#  <td class="table-body__cell u-center-text">3,102</td>,
#  <td class="table-body__cell u-center-text">2,790</td>,
#  <td class="table-body__cell u-center-text">3,057</td>,
#  <td class="table-body__cell u-center-text">2,218</td>,
#  <td class="table-body__cell u-center-text">3,448</td>,
#  <td class="table-body__cell u-center-text">2,941</td>,
#  <td class="table-body__cell u-center-text">1,687</td>,
#  <td class="table-body__cell u-center-text">2,582</td>,
#  <td class="table-body__cell u-center-text">1,641</td>,
#  <td class="table-body__cell u-center-text">1,662</td>,
#  <td class="table-body__cell u-center-text">1,052</td>,
#  <td class="table-body__cell u-center-text">1,044</td>,
#  <td class="table-body__cell u-center-text">1,446</td>,
#  <td class="table-body__cell u-center-text">813</td>,
#  <td class="table-body__cell u-center-text">808</td>,
#  <td class="table-body__cell u-center-text">525</td>,
# ...

# %%
all_points=[]
for tag in selected_data:    
    all_points.append(tag.text.strip())
all_points
# Out:
# ['4,516',
#  '3,102',
#  '2,790',
#  '3,057',
#  '2,218',
#  '3,448',
#  '2,941',
#  '1,687',
#  '2,582',
#  '1,641',
#  '1,662',
#  '1,052',
#  '1,044',
#  '1,446',
#  '813',
#  '808',
#  '525',
#  '617']

# %%
points = match[::2]
points
# Out:
# [<td class="table-body__cell u-center-text">39</td>,
#  <td class="table-body__cell u-center-text">27</td>,
#  <td class="table-body__cell u-center-text">27</td>,
#  <td class="table-body__cell u-center-text">30</td>,
#  <td class="table-body__cell u-center-text">22</td>,
#  <td class="table-body__cell u-center-text">37</td>,
#  <td class="table-body__cell u-center-text">32</td>,
#  <td class="table-body__cell u-center-text">21</td>,
#  <td class="table-body__cell u-center-text">38</td>,
#  <td class="table-body__cell u-center-text">30</td>,
#  <td class="table-body__cell u-center-text">33</td>,
#  <td class="table-body__cell u-center-text">24</td>,
#  <td class="table-body__cell u-center-text">28</td>,
#  <td class="table-body__cell u-center-text">42</td>,
#  <td class="table-body__cell u-center-text">28</td>,
#  <td class="table-body__cell u-center-text">31</td>,
#  <td class="table-body__cell u-center-text">24</td>,
#  <td class="table-body__cell u-center-text">41</td>]

# %%
matchs = match[::2]
matchs
# Out:
# [<td class="table-body__cell u-center-text">39</td>,
#  <td class="table-body__cell u-center-text">27</td>,
#  <td class="table-body__cell u-center-text">27</td>,
#  <td class="table-body__cell u-center-text">30</td>,
#  <td class="table-body__cell u-center-text">22</td>,
#  <td class="table-body__cell u-center-text">37</td>,
#  <td class="table-body__cell u-center-text">32</td>,
#  <td class="table-body__cell u-center-text">21</td>,
#  <td class="table-body__cell u-center-text">38</td>,
#  <td class="table-body__cell u-center-text">30</td>,
#  <td class="table-body__cell u-center-text">33</td>,
#  <td class="table-body__cell u-center-text">24</td>,
#  <td class="table-body__cell u-center-text">28</td>,
#  <td class="table-body__cell u-center-text">42</td>,
#  <td class="table-body__cell u-center-text">28</td>,
#  <td class="table-body__cell u-center-text">31</td>,
#  <td class="table-body__cell u-center-text">24</td>,
#  <td class="table-body__cell u-center-text">41</td>]

# %%
all_match=[]
for tag in matchs:    
    all_match.append(tag.text.strip())
all_match
# Out:
# ['39',
#  '27',
#  '27',
#  '30',
#  '22',
#  '37',
#  '32',
#  '21',
#  '38',
#  '30',
#  '33',
#  '24',
#  '28',
#  '42',
#  '28',
#  '31',
#  '24',
#  '41']

# %%
rating = soup.find_all('td', class_="table-body__cell u-text-right rating")
rating
# Out:
# [<td class="table-body__cell u-text-right rating">116</td>,
#  <td class="table-body__cell u-text-right rating">115</td>,
#  <td class="table-body__cell u-text-right rating">103</td>,
#  <td class="table-body__cell u-text-right rating">102</td>,
#  <td class="table-body__cell u-text-right rating">101</td>,
#  <td class="table-body__cell u-text-right rating">93</td>,
#  <td class="table-body__cell u-text-right rating">92</td>,
#  <td class="table-body__cell u-text-right rating">80</td>,
#  <td class="table-body__cell u-text-right rating">68</td>,
#  <td class="table-body__cell u-text-right rating">55</td>,
#  <td class="table-body__cell u-text-right rating">50</td>,
#  <td class="table-body__cell u-text-right rating">44</td>,
#  <td class="table-body__cell u-text-right rating">37</td>,
#  <td class="table-body__cell u-text-right rating">34</td>,
#  <td class="table-body__cell u-text-right rating">29</td>,
#  <td class="table-body__cell u-text-right rating">26</td>,
# ...

# %%
all_rating=[]
for tag in rating:    
    all_rating.append(tag.text.strip())
all_rating
# Out:
# ['116',
#  '115',
#  '103',
#  '102',
#  '101',
#  '93',
#  '92',
#  '80',
#  '68',
#  '55',
#  '50',
#  '44',
#  '37',
#  '34',
#  '29',
#  '26',
#  '22',
#  '15']

# %%
import pandas as pd
df= pd.DataFrame({'team':team_name,'match':all_match,'points':all_points,'rating':all_rating})
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[55], line 2
#       1 import pandas as pd
# ----> 2 df= pd.DataFrame({'team':team_name,'match':all_match,'points':all_points,'rating':all_rating})
#       3 df
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:664, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     658     mgr = self._init_mgr(
#     659         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     660     )
#     662 elif isinstance(data, dict):
#     663     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 664     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     665 elif isinstance(data, ma.MaskedArray):
#     666     import numpy.ma.mrecords as mrecords
#
# ...

# %%
import pandas as pd
df= pd.DataFrame({'team':team_name})
df
# Out:
#              team
# 0       Australia
# 1           India
# 2        Pakistan
# 3         England
# 4     New Zealand
# 5    South Africa
# 6       Sri Lanka
# 7      Bangladesh
# 8     Afghanistan
# 9     West Indies
# 10       Zimbabwe
# 11       Scotland
# 12        Ireland
# 13    Netherlands
# 14          Nepal
# 15        Namibia
# 16  United States
# 17           Oman
# 18            UAE

# %%
import pandas as pd
df= pd.DataFrame({'match':all_match})
df
# Out:
#    match
# 0     39
# 1     27
# 2     27
# 3     30
# 4     22
# 5     37
# 6     32
# 7     21
# 8     38
# 9     30
# 10    33
# 11    24
# 12    28
# 13    42
# 14    28
# 15    31
# 16    24
# 17    41

# %%
rank_match = soup.find('td', class_="rankings-block__banner--matches")
rank_match
# Out:
# <td class="rankings-block__banner--matches">26</td>

# %%
rank.match.text
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 rank.match.text
#
# NameError: name 'rank' is not defined

# %%
rank_match.text
# Out:
# '26'

# %%
all_match.append(rank_match.text)
all_match
# Out:
# ['39',
#  '27',
#  '27',
#  '30',
#  '22',
#  '37',
#  '32',
#  '21',
#  '38',
#  '30',
#  '33',
#  '24',
#  '28',
#  '42',
#  '28',
#  '31',
#  '24',
#  '41',
#  '26']

# %%
all_match.insert(0, rank_match.text)

# %%
all_match
# Out:
# ['26',
#  '39',
#  '27',
#  '27',
#  '30',
#  '22',
#  '37',
#  '32',
#  '21',
#  '38',
#  '30',
#  '33',
#  '24',
#  '28',
#  '42',
#  '28',
#  '31',
#  '24',
#  '41',
#  '26']
